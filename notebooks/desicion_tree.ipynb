# %%
import pandas as pd
import numpy as np
from typing import Tuple, List, Dict
import matplotlib.pyplot as plt
import math

from scipy.optimize import minimize

import sys
sys.path.insert(0, '../scripts/')
import utils as utl

# %%
df = pd.read_csv('../data/1.raw/customerClassification.csv')#, parse_dates=['DateTime'],index_col=['DateTime'])
df.columns
X_cols = ['Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
       'Work_Experience', 'Spending_Score', 'Family_Size',
       'Segmentation']
X_cat_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession',
       'Spending_Score', 'Segmentation']
y_col = 'Var_1'

X = df[X_cols]
X = X.fillna(0)

# for cat in X_cat_cols:
#     X[cat] = X[cat].astype('category').cat.codes

# for c in X.columns:
#     X[c] = utl.min_max_scaling(X[c])[0]


y = df[y_col].fillna(0).astype('category').cat.codes

# %%
def entropy(y: pd.Series) -> float:
    """Calculates the entropy of y

    Parameters
    ----------
    y : pd.Series
        Categorical value for which the entropy will be calculated

    Returns
    -------
    float
        Entropy
    """
    entropy = 0
    ntt = len(y)
    if ntt != 0:
        for u in y.unique():
            y_c = y.loc[y==u]
            p = len(y_c)/ntt
            if p != 0:
                entropy += -p*math.log2(p)
    return entropy

# %%
def get_splits(x:pd.Series, y:pd.Series) -> np.array:
    """Returns the splits of the categorical data x, using the median x for each category of y

    Parameters
    ----------
    x : pd.Series
        Input data for which the splits will be calculated
    y : pd.Series
        Target categorical data 

    Returns
    -------
    np.array
        _description_
    """
    vals = []
    for u in y.unique():
        x_np = x.loc[y==u].to_numpy()
        vals.append(np.median(x_np))
    vals_sorted = np.sort(np.array(vals))
    _, idx = np.unique(vals_sorted, return_index=True)
    return vals_sorted[np.sort(idx)]

# %%
def iloc_ranges(y: pd.Series, x: pd.Series, splits: List, i: int) -> pd.Series:
    """Filters the data from the series y for which the continuous data x is between the values split[i-1] and split[i]

    Parameters
    ----------
    x : pd.Series
        Continuous data to use as base for the filtering
    y : pd.Series or pd.DataFrame
        Data to be filtered
    splits : List
        Values at which the values of x can be splitted
    i : int
        Index of the split to be used


    Returns
    -------
    pd.Series
        _description_
    """
    if len(x) > 0:
        if i > 0 and i < len(splits):
            Sv = y.loc[(x>splits[i-1]) & (x<=splits[i])]
        elif i == 0:
            Sv = y.loc[x<=splits[0]]
        else:
            Sv = y.loc[x>splits[-1]]
        return Sv
    return pd.Series([])

# %%
def info_gain_cat(x:pd.Series, y:pd.Series) -> float:
    """Calculates the info gain of using a given categorical attribute to describe categorical data

    Parameters
    ----------
    x : pd.Series
        Categorical values of the attribute
    y : pd.Series
        Categorical target

    Returns
    -------
    float
        Information gain
    """
    ES = entropy(y)
    ESv = 0
    nt = len(y)
    if nt != 0:
        for u in x.unique():
            Sv = y.loc[x==u]
            n = len(Sv)        
            ESv += - (n/nt)*entropy(Sv)
    return ES - ESv

def info_gain_con(x:pd.Series, y:pd.Series) -> float:
    """Calculates the info gain of using a given continuous attribute to describe categorical data

    Parameters
    ----------
    x : pd.Series
        Categorical values of the attribute
    y : pd.Series
        Categorical target

    Returns
    -------
    float
        Information gain
    """
    splits = get_splits(x, y)
    ES = entropy(y)
    ESv = 0
    nt = len(y)
    if nt != 0:
        for i in range(len(splits) + 1):
            Sv = iloc_ranges(y, x, splits, i)
            n = len(Sv)
            ESv += - (n/nt)*entropy(Sv)
    return ES - ESv

def get_max_ig(X: pd.DataFrame, y: pd.Series, X_cat_cols: List) -> str:
    dct = {}
    cols = list(X.columns)
    for attr in cols:
        if attr in X_cat_cols:
            dct[attr] = info_gain_cat(X[attr], y)
        else:
            dct[attr] = info_gain_con(X[attr], y)
    return max(dct, key=dct.get)

# %%
class Decision_Tree:
    def __init__(self) -> None:
        pass

    def new_nodes(self, X: pd.DataFrame, y: pd.Series, attr_max_gain: str, X_cat_cols) -> Dict:
        dct_res = {}
        cols = list(X.columns)
        cols.remove(attr_max_gain)
        X_upd = X[cols]
        Xcc = X_cat_cols.copy()
        if attr_max_gain in X_cat_cols:
            Xcc.remove(attr_max_gain)
        
        dct_res['attr'] = attr_max_gain
        if attr_max_gain in X_cat_cols:
            dct_res['type'] = 'cat'
            dct_res['vals'] = X[attr_max_gain].unique()
            childs = {}
            for u in dct_res['vals']:
                Xn = X_upd.loc[X[attr_max_gain]==u]
                yn = y.loc[X[attr_max_gain]==u]
                if len(yn)>0:
                    childs[u] = self.des_tree_nodes(Xn, yn, Xcc)
            dct_res['res'] = childs
        else:
            dct_res['type'] = 'cont'
            splits = get_splits(X[attr_max_gain], y)
            dct_res['vals'] = splits
            childs = {}
            for i in range(len(splits) + 1):                
                Xn = iloc_ranges(X_upd, X[attr_max_gain], splits, i)
                yn = iloc_ranges(y, X[attr_max_gain], splits, i)
                if len(yn)>0:
                    childs[str(i)] = self.des_tree_nodes(Xn, yn, Xcc)
            dct_res['res'] = childs
        return dct_res
    
    def des_tree_nodes(self, X: pd.DataFrame, y: pd.Series, X_cat_cols):
        cols = list(X.columns)
        attr_max_gain = get_max_ig(X, y, X_cat_cols)
        cols.remove(attr_max_gain)
        if len(cols)!=0:
            out = self.new_nodes(X, y, attr_max_gain, X_cat_cols)
            return out
        y_count = {}
        for u in y.unique():
            y_count[u] = y.loc[y==u].count()
        out = max(y_count, key=y_count.get)
        return out

# %%
dt = Decision_Tree()
res_dict = dt.des_tree_nodes(X, y, X_cat_cols)
res_dict
# Out:
# {'attr': 'Gender',
#  'type': 'cat',
#  'vals': array(['Male', 'Female'], dtype=object),
#  'res': {'Male': {'attr': 'Work_Experience',
#    'type': 'cont',
#    'vals': array([1.]),
#    'res': {'0': {'attr': 'Ever_Married',
#      'type': 'cat',
#      'vals': array(['No', 'Yes', 0], dtype=object),
#      'res': {'No': {'attr': 'Spending_Score',
#        'type': 'cat',
#        'vals': array(['Low'], dtype=object),
#        'res': {'Low': {'attr': 'Segmentation',
#          'type': 'cat',
#          'vals': array(['D', 'C', 'B', 'A'], dtype=object),
#          'res': {'D': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['No', 'Yes', 0], dtype=object),
#            'res': {'No': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([21. , 21.5, 22. , 23.5]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare', 'Doctor', 'Marketing', 'Artist', 'Entertainment'],
#                      dtype=object),
#                'res': {'Healthcare': 6,
#                 'Doctor': 6,
#                 'Marketing': 1,
#                 'Artist': 4,
#                 'Entertainment': 6}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare', 'Doctor', 0, 'Marketing', 'Engineer', 'Artist'],
#                      dtype=object),
#                'res': {'Healthcare': 6,
#                 'Doctor': 2,
#                 0: 1,
#                 'Marketing': 4,
#                 'Engineer': 6,
#                 'Artist': 6}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare', 'Marketing', 0, 'Entertainment', 'Doctor', 'Artist',
#                       'Engineer'], dtype=object),
#                'res': {'Healthcare': 6,
#                 'Marketing': 6,
#                 0: 4,
#                 'Entertainment': 4,
#                 'Doctor': 6,
#                 'Artist': 6,
#                 'Engineer': 4}},
#               '4': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2. , 3. , 3.5, 4. ]),
#                'res': {'0': 6, '1': 6, '3': 6, '4': 6}}}},
#             'Yes': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([28. , 28.5, 30. , 30.5, 33.5]),
#              'res': {'0': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([0. , 2.5, 3. , 3.5]),
#                'res': {'0': 3, '1': 6, '2': 6, '4': 6}},
#               '2': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([0., 2., 3., 4.]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 3}},
#               '4': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([0., 2., 3., 4., 6.]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 6}},
#               '5': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1., 2., 3.]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6}}}},
#             0: {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([21. , 27.5]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare'], dtype=object),
#                'res': {'Healthcare': 3}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array([0], dtype=object),
#                'res': {0: 6}}}}}},
#           'C': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['Yes', 'No', 0], dtype=object),
#            'res': {'Yes': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([29.5, 33. , 39. , 48.5]),
#              'res': {'0': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([4., 5.]),
#                'res': {'0': 6, '1': 6, '2': 6}},
#               '1': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3., 4.]),
#                'res': {'0': 6, '1': 6, '2': 6}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}},
#               '4': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor', 'Lawyer', 'Artist', 'Entertainment', 'Executive'],
#                      dtype=object),
#                'res': {'Doctor': 6,
#                 'Lawyer': 6,
#                 'Artist': 4,
#                 'Entertainment': 6,
#                 'Executive': 6}}}},
#             'No': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Healthcare', 'Doctor', 'Marketing', 'Entertainment', 'Artist'],
#                    dtype=object),
#              'res': {'Healthcare': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([25.5, 26. , 28. , 29. , 29.5, 33. ]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6, '5': 6}},
#               'Doctor': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2. , 4. , 4.5, 5. ]),
#                'res': {'0': 3, '1': 6, '3': 4}},
#               'Marketing': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([0. , 2. , 4. , 4.5, 5. ]),
#                'res': {'0': 0, '1': 7, '2': 3, '4': 6}},
#               'Entertainment': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([19., 24.]),
#                'res': {'0': 6, '2': 4}},
#               'Artist': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([31., 33.]),
#                'res': {'0': 2, '1': 3}}}},
#             0: {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([45.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}}}}}},
#           'B': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['No', 'Yes'], dtype=object),
#            'res': {'No': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2.5, 3. , 3.5, 4. ]),
#              'res': {'0': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([29., 31.]),
#                'res': {'0': 6, '1': 4, '2': 4}},
#               '1': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([24., 27., 31., 32.]),
#                'res': {'0': 3, '1': 4, '2': 6, '4': 6}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor', 'Healthcare'], dtype=object),
#                'res': {'Doctor': 6, 'Healthcare': 6}},
#               '4': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([28. , 28.5, 29.5]),
#                'res': {'0': 6, '2': 4, '3': 6}}}},
#             'Yes': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([26. , 29. , 32. , 38. , 39. , 39.5, 43. ]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare', 'Entertainment', 'Artist'], dtype=object),
#                'res': {'Healthcare': 6, 'Entertainment': 3, 'Artist': 0}},
#               '1': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3. , 3.5, 4. , 6. ]),
#                'res': {'0': 6, '2': 6, '3': 6, '4': 4}},
#               '2': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1., 3., 4.]),
#                'res': {'0': 3, '1': 6, '2': 6, '3': 6}},
#               '3': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1. , 1.5, 4. ]),
#                'res': {'0': 6, '2': 6, '3': 6}},
#               '4': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1., 2., 3.]),
#                'res': {'0': 6, '1': 6, '2': 1}},
#               '6': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Entertainment', 'Doctor'], dtype=object),
#                'res': {'Artist': 6, 'Entertainment': 6, 'Doctor': 2}},
#               '7': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 0, 'Entertainment', 'Lawyer', 'Doctor'], dtype=object),
#                'res': {'Artist': 6,
#                 0: 6,
#                 'Entertainment': 6,
#                 'Lawyer': 6,
#                 'Doctor': 6}}}}}},
#           'A': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['Yes', 'No', 0], dtype=object),
#            'res': {'Yes': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([0. , 0.5, 1. , 2. , 3. ]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Doctor', 'Healthcare', 'Entertainment'], dtype=object),
#                'res': {'Artist': 6,
#                 'Doctor': 6,
#                 'Healthcare': 6,
#                 'Entertainment': 1}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array([0, 'Marketing', 'Artist', 'Engineer', 'Doctor', 'Entertainment'],
#                      dtype=object),
#                'res': {0: 6,
#                 'Marketing': 6,
#                 'Artist': 6,
#                 'Engineer': 2,
#                 'Doctor': 6,
#                 'Entertainment': 6}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Artist', 'Healthcare', 'Marketing', 'Doctor',
#                       'Lawyer'], dtype=object),
#                'res': {'Entertainment': 6,
#                 'Artist': 6,
#                 'Healthcare': 3,
#                 'Marketing': 3,
#                 'Doctor': 6,
#                 'Lawyer': 6}},
#               '4': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Doctor', 'Artist', 'Executive', 'Engineer',
#                       'Healthcare'], dtype=object),
#                'res': {'Entertainment': 6,
#                 'Doctor': 6,
#                 'Artist': 6,
#                 'Executive': 6,
#                 'Engineer': 6,
#                 'Healthcare': 6}},
#               '5': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([29.5, 31. , 32. , 39.5, 57. ]),
#                'res': {'0': 6, '1': 2, '2': 6, '3': 3, '4': 6}}}},
#             'No': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([0. , 1.5, 2. , 2.5, 3. ]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Entertainment', 'Engineer'], dtype=object),
#                'res': {'Artist': 4, 'Entertainment': 3, 'Engineer': 4}},
#               '1': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([35., 40., 47., 59.]),
#                'res': {'0': 4, '1': 6, '2': 6, '3': 6, '4': 6}},
#               '2': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([28., 33.]),
#                'res': {'0': 6, '1': 6, '2': 6}},
#               '4': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare', 'Artist', 'Executive', 'Marketing', 'Engineer',
#                       'Entertainment', 'Doctor'], dtype=object),
#                'res': {'Healthcare': 2,
#                 'Artist': 2,
#                 'Executive': 6,
#                 'Marketing': 3,
#                 'Engineer': 6,
#                 'Entertainment': 6,
#                 'Doctor': 6}},
#               '5': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([27.5, 29. ]),
#                'res': {'0': 6, '1': 4, '2': 6}}}},
#             0: {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([27., 50.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Doctor'], dtype=object),
#                'res': {'Executive': 4, 'Doctor': 2}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Lawyer'], dtype=object),
#                'res': {'Lawyer': 4}}}}}}}}}},
#       'Yes': {'attr': 'Spending_Score',
#        'type': 'cat',
#        'vals': array(['High', 'Average', 'Low'], dtype=object),
#        'res': {'High': {'attr': 'Graduated',
#          'type': 'cat',
#          'vals': array(['Yes', 'No', 0], dtype=object),
#          'res': {'Yes': {'attr': 'Segmentation',
#            'type': 'cat',
#            'vals': array(['B', 'D', 'A', 'C'], dtype=object),
#            'res': {'B': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2. , 2.5, 4. ]),
#              'res': {'0': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([52., 54., 60., 63., 66.]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 6, '5': 6}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Healthcare', 0, 'Lawyer', 'Artist', 'Entertainment'],
#                      dtype=object),
#                'res': {'Executive': 6,
#                 'Healthcare': 6,
#                 0: 6,
#                 'Lawyer': 6,
#                 'Artist': 6,
#                 'Entertainment': 6}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Lawyer', 'Artist'], dtype=object),
#                'res': {'Executive': 6, 'Lawyer': 6, 'Artist': 6}}}},
#             'D': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2. , 6.5]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Healthcare', 'Entertainment', 'Executive', 'Lawyer'],
#                      dtype=object),
#                'res': {'Artist': 6,
#                 'Healthcare': 6,
#                 'Entertainment': 3,
#                 'Executive': 6,
#                 'Lawyer': 6}},
#               '1': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([38., 43., 57.]),
#                'res': {'0': 3, '1': 6, '2': 6, '3': 6}},
#               '2': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([53.]),
#                'res': {'0': 4}}}},
#             'A': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2., 4.]),
#              'res': {'0': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([37. , 75. , 86.5]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6}},
#               '1': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([38. , 49.5]),
#                'res': {'0': 6, '1': 6, '2': 6}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Executive'], dtype=object),
#                'res': {'Entertainment': 3, 'Executive': 6}}}},
#             'C': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Artist', 'Executive', 'Lawyer', 'Entertainment', 'Marketing',
#                     'Doctor', 'Healthcare'], dtype=object),
#              'res': {'Artist': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([60.5, 64. ]),
#                'res': {'0': 6, '1': 6, '2': 6}},
#               'Executive': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.5, 3. , 4. , 5. ]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 6}},
#               'Lawyer': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 6, '1': 6}},
#               'Entertainment': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([65.]),
#                'res': {'0': 6}},
#               'Marketing': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([63.]),
#                'res': {'0': 6, '1': 6}},
#               'Doctor': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([51. , 65.5]),
#                'res': {'0': 6, '1': 6, '2': 6}},
#               'Healthcare': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([42.5]),
#                'res': {'0': 6, '1': 6}}}}}},
#           'No': {'attr': 'Age',
#            'type': 'cont',
#            'vals': array([45. , 49. , 56.5, 57. , 62.5, 65. ]),
#            'res': {'0': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['A', 'D', 'B', 'C'], dtype=object),
#              'res': {'A': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3. , 4. , 4.5]),
#                'res': {'0': 4, '1': 6, '3': 6}},
#               'D': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Entertainment', 'Doctor', 'Healthcare'], dtype=object),
#                'res': {'Executive': 6,
#                 'Entertainment': 6,
#                 'Doctor': 6,
#                 'Healthcare': 4}},
#               'B': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Doctor', 'Marketing', 'Healthcare', 'Artist'],
#                      dtype=object),
#                'res': {'Executive': 6,
#                 'Doctor': 3,
#                 'Marketing': 7,
#                 'Healthcare': 4,
#                 'Artist': 4}},
#               'C': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Marketing'], dtype=object),
#                'res': {'Executive': 6, 'Marketing': 7}}}},
#             '1': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Artist', 'Executive', 'Entertainment'], dtype=object),
#              'res': {'Artist': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3.5]),
#                'res': {'0': 6, '1': 6}},
#               'Executive': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C', 'B', 'A', 'D'], dtype=object),
#                'res': {'C': 6, 'B': 6, 'A': 6, 'D': 2}},
#               'Entertainment': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([4.]),
#                'res': {'0': 4, '1': 6}}}},
#             '2': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['B', 'A', 'C'], dtype=object),
#              'res': {'B': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Healthcare'], dtype=object),
#                'res': {'Executive': 6, 'Healthcare': 7}},
#               'A': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3., 7.]),
#                'res': {'0': 6, '1': 6, '2': 4}},
#               'C': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Lawyer', 'Executive'], dtype=object),
#                'res': {'Lawyer': 6, 'Executive': 6}}}},
#             '3': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([3., 4.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Marketing'], dtype=object),
#                'res': {'Entertainment': 4, 'Marketing': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive'], dtype=object),
#                'res': {'Executive': 6}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive'], dtype=object),
#                'res': {'Executive': 6}}}},
#             '4': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Artist', 'Marketing', 'Executive'], dtype=object),
#              'res': {'Artist': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.5, 4. ]),
#                'res': {'0': 6, '1': 6}},
#               'Marketing': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 3}},
#               'Executive': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['B', 'C'], dtype=object),
#                'res': {'B': 6, 'C': 6}}}},
#             '5': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2.]),
#              'res': {'0': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C', 'B', 'A'], dtype=object),
#                'res': {'C': 6, 'B': 6, 'A': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive'], dtype=object),
#                'res': {'Executive': 6}}}},
#             '6': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Executive', 'Lawyer', 'Doctor', 'Engineer', 0, 'Entertainment'],
#                    dtype=object),
#              'res': {'Executive': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['B', 'A', 'C', 'D'], dtype=object),
#                'res': {'B': 6, 'A': 6, 'C': 6, 'D': 6}},
#               'Lawyer': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2. , 2.5, 9. ]),
#                'res': {'0': 6, '2': 6}},
#               'Doctor': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 6}},
#               'Engineer': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([0., 4.]),
#                'res': {'0': 6, '1': 4}},
#               0: {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3.]),
#                'res': {'0': 6}},
#               'Entertainment': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 6}}}}}},
#           0: {'attr': 'Age',
#            'type': 'cont',
#            'vals': array([60.5]),
#            'res': {'0': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Entertainment'], dtype=object),
#              'res': {'Entertainment': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3.5]),
#                'res': {'0': 6, '1': 6}}}},
#             '1': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Executive', 'Lawyer'], dtype=object),
#              'res': {'Executive': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 6}},
#               'Lawyer': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 6}}}}}}}},
#         'Average': {'attr': 'Family_Size',
#          'type': 'cont',
#          'vals': array([2., 3.]),
#          'res': {'0': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['No', 'Yes', 0], dtype=object),
#            'res': {'No': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['C', 'D', 'B', 'A'], dtype=object),
#              'res': {'C': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([40. , 50. , 57. , 57.5, 61. , 79. ]),
#                'res': {'0': 6, '1': 6, '2': 6, '4': 6, '5': 6}},
#               'D': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor', 'Artist', 'Executive', 'Healthcare', 'Engineer',
#                       'Entertainment'], dtype=object),
#                'res': {'Doctor': 6,
#                 'Artist': 6,
#                 'Executive': 3,
#                 'Healthcare': 6,
#                 'Engineer': 3,
#                 'Entertainment': 3}},
#               'B': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor', 'Engineer', 'Entertainment', 'Artist', 'Executive', 0],
#                      dtype=object),
#                'res': {'Doctor': 6,
#                 'Engineer': 6,
#                 'Entertainment': 6,
#                 'Artist': 4,
#                 'Executive': 6,
#                 0: 4}},
#               'A': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([30. , 36. , 40. , 46.5]),
#                'res': {'0': 4, '1': 7, '2': 6, '3': 4, '4': 6}}}},
#             'Yes': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['C', 'A', 'D', 'B'], dtype=object),
#              'res': {'C': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Doctor', 'Entertainment', 'Engineer', 0, 'Homemaker',
#                       'Lawyer', 'Executive'], dtype=object),
#                'res': {'Artist': 6,
#                 'Doctor': 6,
#                 'Entertainment': 6,
#                 'Engineer': 3,
#                 0: 6,
#                 'Homemaker': 3,
#                 'Lawyer': 6,
#                 'Executive': 6}},
#               'A': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor', 'Engineer', 'Entertainment', 'Artist', 'Lawyer',
#                       'Healthcare', 'Executive', 'Marketing', 'Homemaker'], dtype=object),
#                'res': {'Doctor': 6,
#                 'Engineer': 6,
#                 'Entertainment': 6,
#                 'Artist': 6,
#                 'Lawyer': 6,
#                 'Healthcare': 6,
#                 'Executive': 6,
#                 'Marketing': 2,
#                 'Homemaker': 4}},
#               'D': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Healthcare', 'Doctor'], dtype=object),
#                'res': {'Artist': 6, 'Healthcare': 6, 'Doctor': 3}},
#               'B': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Artist', 'Doctor', 'Homemaker', 'Engineer',
#                       'Executive'], dtype=object),
#                'res': {'Entertainment': 6,
#                 'Artist': 6,
#                 'Doctor': 6,
#                 'Homemaker': 2,
#                 'Engineer': 6,
#                 'Executive': 6}}}},
#             0: {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([58., 63.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array([0], dtype=object),
#                'res': {0: 4}}}}}},
#           '1': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['No', 'Yes', 0], dtype=object),
#            'res': {'No': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([37., 43., 46., 47.]),
#              'res': {'0': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['D', 'B', 'A', 'C'], dtype=object),
#                'res': {'D': 6, 'B': 6, 'A': 4, 'C': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Engineer', 'Executive', 'Doctor', 'Entertainment'],
#                      dtype=object),
#                'res': {'Artist': 6,
#                 'Engineer': 6,
#                 'Executive': 6,
#                 'Doctor': 6,
#                 'Entertainment': 3}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Doctor', 'Engineer', 'Artist', 'Executive'],
#                      dtype=object),
#                'res': {'Entertainment': 6,
#                 'Doctor': 4,
#                 'Engineer': 6,
#                 'Artist': 6,
#                 'Executive': 1}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer', 'Entertainment'], dtype=object),
#                'res': {'Engineer': 6, 'Entertainment': 6}},
#               '4': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C', 'B', 'D', 'A'], dtype=object),
#                'res': {'C': 6, 'B': 6, 'D': 6, 'A': 6}}}},
#             'Yes': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Artist', 'Executive', 'Entertainment', 'Doctor', 'Engineer',
#                     'Healthcare', 0, 'Marketing'], dtype=object),
#              'res': {'Artist': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C', 'B', 'A', 'D'], dtype=object),
#                'res': {'C': 6, 'B': 6, 'A': 6, 'D': 2}},
#               'Executive': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['A', 'B'], dtype=object),
#                'res': {'A': 6, 'B': 6}},
#               'Entertainment': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C', 'B', 'A', 'D'], dtype=object),
#                'res': {'C': 6, 'B': 6, 'A': 3, 'D': 4}},
#               'Doctor': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([48., 50.]),
#                'res': {'0': 6, '1': 6, '2': 6}},
#               'Engineer': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([37., 44., 54.]),
#                'res': {'0': 3, '2': 4, '3': 6}},
#               'Healthcare': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([73.]),
#                'res': {'0': 6}},
#               0: {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([62.]),
#                'res': {'0': 6}},
#               'Marketing': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([59.]),
#                'res': {'0': 6}}}},
#             0: {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([20.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Marketing'], dtype=object),
#                'res': {'Marketing': 3}}}}}},
#           '2': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['Yes', 'No', 0], dtype=object),
#            'res': {'Yes': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['B', 'C', 'A', 'D'], dtype=object),
#              'res': {'B': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Artist', 'Doctor', 'Executive', 'Healthcare',
#                       'Engineer', 0], dtype=object),
#                'res': {'Entertainment': 6,
#                 'Artist': 6,
#                 'Doctor': 6,
#                 'Executive': 6,
#                 'Healthcare': 4,
#                 'Engineer': 6,
#                 0: 6}},
#               'C': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Executive', 'Entertainment', 'Engineer', 'Doctor',
#                       'Healthcare', 'Homemaker'], dtype=object),
#                'res': {'Artist': 6,
#                 'Executive': 6,
#                 'Entertainment': 6,
#                 'Engineer': 6,
#                 'Doctor': 6,
#                 'Healthcare': 6,
#                 'Homemaker': 6}},
#               'A': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([37. , 43.5, 46.5, 49. ]),
#                'res': {'0': 3, '1': 6, '3': 6, '4': 6}},
#               'D': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([36.5, 53. ]),
#                'res': {'0': 3, '1': 6}}}},
#             'No': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['A', 'B', 'D', 'C'], dtype=object),
#              'res': {'A': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([40.5, 42.5]),
#                'res': {'0': 4, '1': 4, '2': 6}},
#               'B': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Engineer', 'Artist', 'Executive', 'Doctor',
#                       'Healthcare', 0], dtype=object),
#                'res': {'Entertainment': 4,
#                 'Engineer': 6,
#                 'Artist': 6,
#                 'Executive': 6,
#                 'Doctor': 6,
#                 'Healthcare': 4,
#                 0: 3}},
#               'D': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare', 'Entertainment', 0, 'Executive', 'Engineer',
#                       'Doctor', 'Marketing'], dtype=object),
#                'res': {'Healthcare': 7,
#                 'Entertainment': 3,
#                 0: 4,
#                 'Executive': 4,
#                 'Engineer': 4,
#                 'Doctor': 6,
#                 'Marketing': 4}},
#               'C': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Artist', 'Executive', 'Doctor'], dtype=object),
#                'res': {'Entertainment': 6,
#                 'Artist': 6,
#                 'Executive': 6,
#                 'Doctor': 4}}}},
#             0: {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([49., 50.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Healthcare'], dtype=object),
#                'res': {'Entertainment': 4, 'Healthcare': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}},
#               '2': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['B'], dtype=object),
#                'res': {'B': 6}}}}}}}},
#         'Low': {'attr': 'Graduated',
#          'type': 'cat',
#          'vals': array(['No', 'Yes', 0], dtype=object),
#          'res': {'No': {'attr': 'Segmentation',
#            'type': 'cat',
#            'vals': array(['A', 'D', 'B', 'C'], dtype=object),
#            'res': {'A': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([1. , 2. , 3. , 3.5, 5. ]),
#              'res': {'0': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([35.5, 74. , 74.5]),
#                'res': {'0': 4, '1': 6, '3': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor', 'Executive', 'Marketing', 'Artist', 'Lawyer',
#                       'Entertainment', 'Engineer', 'Healthcare'], dtype=object),
#                'res': {'Doctor': 6,
#                 'Executive': 6,
#                 'Marketing': 6,
#                 'Artist': 6,
#                 'Lawyer': 6,
#                 'Entertainment': 6,
#                 'Engineer': 4,
#                 'Healthcare': 3}},
#               '2': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([44., 51.]),
#                'res': {'0': 4, '1': 6, '2': 4}},
#               '4': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([33. , 39.5, 47. , 52. , 57. ]),
#                'res': {'0': 6, '1': 4, '2': 4, '3': 0, '4': 6, '5': 3}},
#               '5': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([35. , 37.5]),
#                'res': {'0': 4, '2': 4}}}},
#             'D': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([1., 2., 3., 4., 5.]),
#              'res': {'0': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([52. , 65. , 76.5, 78.5, 79. ]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 6, '5': 6}},
#               '1': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([38.5, 43. , 49. , 67. ]),
#                'res': {'0': 4, '1': 7, '2': 4, '3': 6, '4': 6}},
#               '2': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([27. , 30.5, 35. , 41. ]),
#                'res': {'0': 6, '2': 4, '3': 1}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive', 'Marketing', 'Engineer', 'Doctor'], dtype=object),
#                'res': {'Executive': 4,
#                 'Marketing': 4,
#                 'Engineer': 6,
#                 'Doctor': 4}},
#               '4': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([28., 40., 47., 57., 71.]),
#                'res': {'0': 1, '1': 6, '2': 6, '3': 4, '4': 3}},
#               '5': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([49., 55.]),
#                'res': {'0': 4, '1': 4, '2': 4}}}},
#             'B': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([1., 2.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Lawyer', 'Entertainment', 'Executive'], dtype=object),
#                'res': {'Artist': 6,
#                 'Lawyer': 6,
#                 'Entertainment': 6,
#                 'Executive': 6}},
#               '1': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([43., 45., 69.]),
#                'res': {'0': 6, '1': 4, '2': 6, '3': 6}},
#               '2': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([46., 55.]),
#                'res': {'0': 6, '1': 4, '2': 4}}}},
#             'C': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Executive', 'Artist', 'Lawyer'], dtype=object),
#              'res': {'Executive': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([73.]),
#                'res': {'0': 6, '1': 6}},
#               'Artist': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([35. , 37. , 56. , 61.5]),
#                'res': {'0': 4, '1': 3, '2': 6, '4': 6}},
#               'Lawyer': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([69.]),
#                'res': {'0': 6}}}}}},
#           'Yes': {'attr': 'Family_Size',
#            'type': 'cont',
#            'vals': array([2. , 2.5]),
#            'res': {'0': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['A', 'D', 'B', 'C'], dtype=object),
#              'res': {'A': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Executive', 'Entertainment', 'Homemaker', 'Lawyer',
#                       'Healthcare', 'Engineer', 'Doctor', 0, 'Marketing'], dtype=object),
#                'res': {'Artist': 6,
#                 'Executive': 6,
#                 'Entertainment': 6,
#                 'Homemaker': 4,
#                 'Lawyer': 6,
#                 'Healthcare': 6,
#                 'Engineer': 3,
#                 'Doctor': 6,
#                 0: 6,
#                 'Marketing': 6}},
#               'D': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([32. , 35. , 37.5, 54. , 57.5, 60. ]),
#                'res': {'0': 6,
#                 '1': 6,
#                 '2': 6,
#                 '3': 6,
#                 '4': 6,
#                 '5': 6,
#                 '6': 6}},
#               'B': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([47., 51., 57., 65., 66.]),
#                'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 6, '5': 6}},
#               'C': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([44.5, 49. , 56.5, 59. , 63.5, 68. ]),
#                'res': {'0': 6,
#                 '1': 6,
#                 '2': 6,
#                 '3': 6,
#                 '4': 6,
#                 '5': 6,
#                 '6': 6}}}},
#             '2': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['A', 'B', 'D', 'C'], dtype=object),
#              'res': {'A': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Artist', 'Executive', 'Doctor', 'Healthcare',
#                       'Lawyer'], dtype=object),
#                'res': {'Entertainment': 6,
#                 'Artist': 6,
#                 'Executive': 2,
#                 'Doctor': 6,
#                 'Healthcare': 6,
#                 'Lawyer': 6}},
#               'B': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Entertainment', 'Healthcare', 'Homemaker', 'Executive',
#                       'Doctor'], dtype=object),
#                'res': {'Artist': 6,
#                 'Entertainment': 6,
#                 'Healthcare': 6,
#                 'Homemaker': 6,
#                 'Executive': 6,
#                 'Doctor': 6}},
#               'D': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([27.5, 32.5, 40. , 42.5, 51. , 56. ]),
#                'res': {'0': 7,
#                 '1': 6,
#                 '2': 6,
#                 '3': 6,
#                 '4': 6,
#                 '5': 3,
#                 '6': 6}},
#               'C': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Executive', 'Entertainment', 'Lawyer'], dtype=object),
#                'res': {'Artist': 6,
#                 'Executive': 6,
#                 'Entertainment': 2,
#                 'Lawyer': 3}}}}}},
#           0: {'attr': 'Profession',
#            'type': 'cat',
#            'vals': array(['Lawyer', 'Entertainment'], dtype=object),
#            'res': {'Lawyer': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([78., 79.]),
#              'res': {'0': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C'], dtype=object),
#                'res': {'C': 6}},
#               '1': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1.]),
#                'res': {'0': 4}},
#               '2': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1.]),
#                'res': {'0': 6}}}},
#             'Entertainment': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([37.]),
#              'res': {'0': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([0.]),
#                'res': {'0': 3}}}}}}}}}},
#       0: {'attr': 'Graduated',
#        'type': 'cat',
#        'vals': array(['No', 'Yes', 0], dtype=object),
#        'res': {'No': {'attr': 'Spending_Score',
#          'type': 'cat',
#          'vals': array(['High', 'Low', 'Average'], dtype=object),
#          'res': {'High': {'attr': 'Family_Size',
#            'type': 'cont',
#            'vals': array([0., 2.]),
#            'res': {'0': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['A', 'D'], dtype=object),
#              'res': {'A': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([61.]),
#                'res': {'0': 4}},
#               'D': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([22., 30.]),
#                'res': {'0': 3, '1': 6}}}},
#             '1': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([61., 81.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Marketing'], dtype=object),
#                'res': {'Marketing': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Executive'], dtype=object),
#                'res': {'Executive': 4}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Lawyer'], dtype=object),
#                'res': {'Lawyer': 6}}}},
#             '2': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['D', 'A'], dtype=object),
#              'res': {'D': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([19., 52.]),
#                'res': {'0': 4, '1': 6}},
#               'A': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([58.]),
#                'res': {'0': 6}}}}}},
#           'Low': {'attr': 'Profession',
#            'type': 'cat',
#            'vals': array(['Healthcare', 'Lawyer', 'Entertainment'], dtype=object),
#            'res': {'Healthcare': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['D', 'C'], dtype=object),
#              'res': {'D': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([20., 22.]),
#                'res': {'0': 6, '1': 4}},
#               'C': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([32.]),
#                'res': {'0': 6, '1': 6}}}},
#             'Lawyer': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([1.]),
#              'res': {'0': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['A'], dtype=object),
#                'res': {'A': 6}}}},
#             'Entertainment': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([28.]),
#              'res': {'0': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 6}}}}}},
#           'Average': {'attr': 'Family_Size',
#            'type': 'cont',
#            'vals': array([3.]),
#            'res': {'0': {'attr': 'Segmentation',
#              'type': 'cat',
#              'vals': array(['A'], dtype=object),
#              'res': {'A': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([43., 60.]),
#                'res': {'0': 3, '1': 4}}}}}}}},
#         'Yes': {'attr': 'Spending_Score',
#          'type': 'cat',
#          'vals': array(['Average', 'High', 'Low'], dtype=object),
#          'res': {'Average': {'attr': 'Segmentation',
#            'type': 'cat',
#            'vals': array(['C', 'A', 'B'], dtype=object),
#            'res': {'C': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Artist', 'Entertainment'], dtype=object),
#              'res': {'Artist': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3., 5.]),
#                'res': {'0': 3, '1': 4}},
#               'Entertainment': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([38.]),
#                'res': {'0': 3}}}},
#             'A': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Artist', 'Doctor', 'Entertainment'], dtype=object),
#              'res': {'Artist': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([37., 56.]),
#                'res': {'0': 3, '1': 6}},
#               'Doctor': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([32.]),
#                'res': {'0': 4}},
#               'Entertainment': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([59.]),
#                'res': {'0': 6}}}},
#             'B': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([55.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Engineer', 'Entertainment'], dtype=object),
#                'res': {'Artist': 6, 'Engineer': 4, 'Entertainment': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}}}}}},
#           'High': {'attr': 'Segmentation',
#            'type': 'cat',
#            'vals': array(['B', 'D'], dtype=object),
#            'res': {'B': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([57.5]),
#              'res': {'0': {'attr': 'Profession',
# ...
#                'type': 'cat',
#                'vals': array(['C', 'B'], dtype=object),
#                'res': {'C': 6, 'B': 6}},
#               'Homemaker': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([3.]),
#                'res': {'0': 6, '1': 6}},
#               'Executive': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2.]),
#                'res': {'0': 6}}}}}},
#           'No': {'attr': 'Spending_Score',
#            'type': 'cat',
#            'vals': array(['Low', 'Average'], dtype=object),
#            'res': {'Low': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([1.]),
#              'res': {'0': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['A', 'B', 'D'], dtype=object),
#                'res': {'A': 6, 'B': 6, 'D': 3}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer'], dtype=object),
#                'res': {'Engineer': 6}}}},
#             'Average': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([4., 5.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Engineer'], dtype=object),
#                'res': {'Artist': 6, 'Engineer': 4}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment'], dtype=object),
#                'res': {'Entertainment': 2}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer'], dtype=object),
#                'res': {'Engineer': 4}}}}}}}},
#         '6': {'attr': 'Spending_Score',
#          'type': 'cat',
#          'vals': array(['Average', 'Low', 'High'], dtype=object),
#          'res': {'Average': {'attr': 'Segmentation',
#            'type': 'cat',
#            'vals': array(['A', 'B', 'C', 'D'], dtype=object),
#            'res': {'A': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2.5, 4. , 7. ]),
#              'res': {'0': {'attr': 'Graduated',
#                'type': 'cat',
#                'vals': array(['Yes', 'No'], dtype=object),
#                'res': {'Yes': 6, 'No': 4}},
#               '1': {'attr': 'Graduated',
#                'type': 'cat',
#                'vals': array(['Yes', 'No'], dtype=object),
#                'res': {'Yes': 6, 'No': 6}},
#               '2': {'attr': 'Graduated',
#                'type': 'cat',
#                'vals': array(['No', 'Yes'], dtype=object),
#                'res': {'No': 4, 'Yes': 7}}}},
#             'B': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['No', 'Yes'], dtype=object),
#              'res': {'No': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer', 'Artist', 'Entertainment', 'Executive'], dtype=object),
#                'res': {'Engineer': 4,
#                 'Artist': 6,
#                 'Entertainment': 6,
#                 'Executive': 2}},
#               'Yes': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([2. , 3. , 3.5, 4. ]),
#                'res': {'0': 6, '1': 5, '3': 6}}}},
#             'C': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['Yes', 'No'], dtype=object),
#              'res': {'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Homemaker', 'Artist', 'Engineer', 'Doctor'], dtype=object),
#                'res': {'Homemaker': 6,
#                 'Artist': 6,
#                 'Engineer': 6,
#                 'Doctor': 6}},
#               'No': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor', 'Artist'], dtype=object),
#                'res': {'Doctor': 6, 'Artist': 6}}}},
#             'D': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['No', 'Yes'], dtype=object),
#              'res': {'No': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer', 'Entertainment'], dtype=object),
#                'res': {'Engineer': 4, 'Entertainment': 4}},
#               'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor'], dtype=object),
#                'res': {'Doctor': 2}}}}}},
#           'Low': {'attr': 'Family_Size',
#            'type': 'cont',
#            'vals': array([1. , 1.5, 2. , 3.5]),
#            'res': {'0': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['Yes', 'No'], dtype=object),
#              'res': {'Yes': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C', 'A', 'D', 'B'], dtype=object),
#                'res': {'C': 6, 'A': 6, 'D': 6, 'B': 6}},
#               'No': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['B', 'A', 'D', 'C'], dtype=object),
#                'res': {'B': 6, 'A': 6, 'D': 6, 'C': 6}}}},
#             '2': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['Yes', 'No'], dtype=object),
#              'res': {'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Homemaker', 'Lawyer', 'Entertainment', 'Doctor',
#                       'Marketing'], dtype=object),
#                'res': {'Artist': 6,
#                 'Homemaker': 6,
#                 'Lawyer': 6,
#                 'Entertainment': 6,
#                 'Doctor': 6,
#                 'Marketing': 6}},
#               'No': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer', 0], dtype=object),
#                'res': {'Engineer': 6, 0: 3}}}},
#             '3': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['No', 'Yes'], dtype=object),
#              'res': {'No': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer'], dtype=object),
#                'res': {'Engineer': 6}},
#               'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Artist', 'Engineer'], dtype=object),
#                'res': {'Entertainment': 6, 'Artist': 4, 'Engineer': 3}}}},
#             '4': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['No', 0, 'Yes'], dtype=object),
#              'res': {'No': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment', 'Artist'], dtype=object),
#                'res': {'Entertainment': 3, 'Artist': 6}},
#               0: {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Lawyer'], dtype=object),
#                'res': {'Lawyer': 6}},
#               'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Lawyer'], dtype=object),
#                'res': {'Artist': 6, 'Lawyer': 1}}}}}},
#           'High': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['No', 'Yes'], dtype=object),
#            'res': {'No': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2.]),
#              'res': {'0': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['D', 'A', 'B', 'C'], dtype=object),
#                'res': {'D': 2, 'A': 6, 'B': 6, 'C': 7}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Homemaker'], dtype=object),
#                'res': {'Homemaker': 6}}}},
#             'Yes': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2. , 2.5, 4. , 5. ]),
#              'res': {'0': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['C', 'B', 'A'], dtype=object),
#                'res': {'C': 6, 'B': 6, 'A': 6}},
#               '2': {'attr': 'Segmentation',
#                'type': 'cat',
#                'vals': array(['B', 'C', 'A', 'D'], dtype=object),
#                'res': {'B': 6, 'C': 6, 'A': 6, 'D': 6}},
#               '3': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}},
#               '4': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist', 'Lawyer'], dtype=object),
#                'res': {'Artist': 6, 'Lawyer': 6}}}}}}}}}},
#       0: {'attr': 'Spending_Score',
#        'type': 'cat',
#        'vals': array(['Low', 'High', 'Average'], dtype=object),
#        'res': {'Low': {'attr': 'Graduated',
#          'type': 'cat',
#          'vals': array(['No', 'Yes'], dtype=object),
#          'res': {'No': {'attr': 'Segmentation',
#            'type': 'cat',
#            'vals': array(['D', 'C', 'B', 'A'], dtype=object),
#            'res': {'D': {'attr': 'Profession',
#              'type': 'cat',
#              'vals': array(['Healthcare', 'Homemaker'], dtype=object),
#              'res': {'Healthcare': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([19., 22.]),
#                'res': {'0': 3, '1': 2}},
#               'Homemaker': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1.]),
#                'res': {'0': 5}}}},
#             'C': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([33.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare'], dtype=object),
#                'res': {'Healthcare': 2}}}},
#             'B': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([53.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}}}},
#             'A': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([51.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Homemaker'], dtype=object),
#                'res': {'Homemaker': 3}}}}}},
#           'Yes': {'attr': 'Segmentation',
#            'type': 'cat',
#            'vals': array(['C', 'B', 'A'], dtype=object),
#            'res': {'C': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([28.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Healthcare'], dtype=object),
#                'res': {'Healthcare': 3}}}},
#             'B': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([35., 39.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor'], dtype=object),
#                'res': {'Doctor': 2}}}},
#             'A': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([40., 41.]),
#              'res': {'0': {'attr': 'Family_Size',
#                'type': 'cont',
#                'vals': array([1.]),
#                'res': {'0': 3}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment'], dtype=object),
#                'res': {'Entertainment': 6}}}}}}}},
#         'High': {'attr': 'Segmentation',
#          'type': 'cat',
#          'vals': array(['D', 'A'], dtype=object),
#          'res': {'D': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['No', 'Yes'], dtype=object),
#            'res': {'No': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([22., 33., 58.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor'], dtype=object),
#                'res': {'Doctor': 6}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer'], dtype=object),
#                'res': {'Engineer': 4}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Marketing'], dtype=object),
#                'res': {'Marketing': 3}}}},
#             'Yes': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([72.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Lawyer'], dtype=object),
#                'res': {'Lawyer': 6}}}}}},
#           'A': {'attr': 'Age',
#            'type': 'cont',
#            'vals': array([31.]),
#            'res': {'0': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array([0], dtype=object),
#              'res': {0: {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor'], dtype=object),
#                'res': {'Doctor': 4}}}}}}}},
#         'Average': {'attr': 'Segmentation',
#          'type': 'cat',
#          'vals': array(['D', 'A', 'B', 'C'], dtype=object),
#          'res': {'D': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['No'], dtype=object),
#            'res': {'No': {'attr': 'Family_Size',
#              'type': 'cont',
#              'vals': array([2., 3.]),
#              'res': {'0': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([49., 72.]),
#                'res': {'0': 3, '1': 6}},
#               '1': {'attr': 'Age',
#                'type': 'cont',
#                'vals': array([37.]),
#                'res': {'0': 4}}}}}},
#           'A': {'attr': 'Age',
#            'type': 'cont',
#            'vals': array([43. , 43.5]),
#            'res': {'0': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['Yes', 'No'], dtype=object),
#              'res': {'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Doctor'], dtype=object),
#                'res': {'Doctor': 6}},
#               'No': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer'], dtype=object),
#                'res': {'Engineer': 4}}}},
#             '2': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['Yes'], dtype=object),
#              'res': {'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}}}}}},
#           'B': {'attr': 'Graduated',
#            'type': 'cat',
#            'vals': array(['Yes', 'No'], dtype=object),
#            'res': {'Yes': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([53. , 61.5]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Entertainment'], dtype=object),
#                'res': {'Entertainment': 2}},
#               '1': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer'], dtype=object),
#                'res': {'Engineer': 6}},
#               '2': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}}}},
#             'No': {'attr': 'Age',
#              'type': 'cont',
#              'vals': array([51.]),
#              'res': {'0': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Engineer'], dtype=object),
#                'res': {'Engineer': 4}}}}}},
#           'C': {'attr': 'Age',
#            'type': 'cont',
#            'vals': array([59.]),
#            'res': {'0': {'attr': 'Graduated',
#              'type': 'cat',
#              'vals': array(['Yes'], dtype=object),
#              'res': {'Yes': {'attr': 'Profession',
#                'type': 'cat',
#                'vals': array(['Artist'], dtype=object),
#                'res': {'Artist': 6}}}}}}}}}}}}}}}}

# %%
X['Ever_Married'].unique()
# Out:
# array(['No', 'Yes', 0], dtype=object)
