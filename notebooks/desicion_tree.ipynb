# %%
import pandas as pd
import numpy as np
from typing import Tuple, List, Dict
import matplotlib.pyplot as plt
import math

from scipy.optimize import minimize

import sys
sys.path.insert(0, '../scripts/')
import utils as utl

# %%
df = pd.read_csv('../data/1.raw/customerClassification.csv')#, parse_dates=['DateTime'],index_col=['DateTime'])
df.columns
X_cols = ['Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
       'Work_Experience', 'Spending_Score', 'Family_Size',
       'Segmentation']
X_cat_cols = ['Gender', 'Ever_Married', 'Graduated', 'Profession',
       'Spending_Score', 'Segmentation']
y_col = 'Var_1'

X = df[X_cols]
X = X.fillna(0)

for cat in X_cat_cols:
    X[cat] = X[cat].astype('category').cat.codes

# for c in X.columns:
#     X[c] = utl.min_max_scaling(X[c])[0]


y = df[y_col].fillna(0).astype('category').cat.codes

# %%
def entropy(y: pd.Series) -> float:
    """Calculates the entropy of y

    Parameters
    ----------
    y : pd.Series
        Categorical value for which the entropy will be calculated

    Returns
    -------
    float
        Entropy
    """
    entropy = 0
    ntt = len(y)
    if ntt != 0:
        for u in y.unique():
            y_c = y.loc[y==u]
            p = len(y_c)/ntt
            if p != 0:
                entropy += -p*math.log2(p)
    return entropy

# %%
def get_splits(x:pd.Series, y:pd.Series) -> np.array:
    """Returns the splits of the categorical data x, using the median x for each category of y

    Parameters
    ----------
    x : pd.Series
        Input data for which the splits will be calculated
    y : pd.Series
        Target categorical data 

    Returns
    -------
    np.array
        Limits of the splits
    """
    vals = []
    for u in y.unique():
        x_np = x.loc[y==u].to_numpy()
        vals.append(np.median(x_np))
    vals_sorted = np.sort(np.unique(np.array(vals)))
    return vals_sorted

# %%
class Decision_Tree:
    def __init__(self) -> None:
        pass

    def new_nodes(self, X: pd.DataFrame, y: pd.Series, attr_max_gain: str, X_cat_cols) -> Dict:
        dct_res = {}
        cols = list(X.columns)
        cols.remove(attr_max_gain)
        X_upd = X[cols]
        Xcc = X_cat_cols.copy()
        if attr_max_gain in X_cat_cols:
            Xcc.remove(attr_max_gain)
        
        dct_res['attr'] = attr_max_gain
        if attr_max_gain in X_cat_cols:
            dct_res['type'] = 'cat'
            dct_res['vals'] = np.sort(X[attr_max_gain].unique())
            childs = {}

            for u in dct_res['vals']:
                Xn = X_upd.loc[X[attr_max_gain]==u]
                yn = y.loc[X[attr_max_gain]==u]
                if len(yn)>0:
                    childs[u] = yn.iloc[0]
                    if len(yn.unique()) > 1:
                        childs[u] = self.des_tree_nodes(Xn, yn, Xcc)
            dct_res['res'] = childs
        else:
            dct_res['type'] = 'cont'
            splits = get_splits(X[attr_max_gain], y)
            dct_res['vals'] = splits
            childs = {}
            for i in range(len(splits) + 1):                
                Xn = iloc_ranges(X_upd, X[attr_max_gain], splits, i)
                yn = iloc_ranges(y, X[attr_max_gain], splits, i)
                if len(yn)>0:
                    childs[str(i)] = self.des_tree_nodes(Xn, yn, Xcc)
            dct_res['res'] = childs
        return dct_res
    
    def des_tree_nodes(self, X: pd.DataFrame, y: pd.Series, X_cat_cols):
        cols = list(X.columns)
        attr_max_gain = self.get_max_ig(X, y, X_cat_cols)
        cols.remove(attr_max_gain)
        if len(cols)!=0:
            out = self.new_nodes(X, y, attr_max_gain, X_cat_cols)
            return out
        y_count = {}
        for u in y.unique():
            y_count[u] = y.loc[y==u].count()
        out = max(y_count, key=y_count.get)
        return out
    
    def info_gain_cat(self, x:pd.Series, y:pd.Series) -> float:
        """Calculates the info gain of using a given categorical attribute to describe categorical data

        Parameters
        ----------
        x : pd.Series
            Categorical values of the attribute
        y : pd.Series
            Categorical target

        Returns
        -------
        float
            Information gain
        """
        ES = entropy(y)
        ESv = 0
        nt = len(y)
        if nt != 0:
            for u in np.sort(x.unique()):
                Sv = y.loc[x==u]
                n = len(Sv)        
                ESv += - (n/nt)*entropy(Sv)
        return ES - ESv

    def info_gain_con(self, x:pd.Series, y:pd.Series) -> float:
        """Calculates the info gain of using a given continuous attribute to describe categorical data

        Parameters
        ----------
        x : pd.Series
            Categorical values of the attribute
        y : pd.Series
            Categorical target

        Returns
        -------
        float
            Information gain
        """
        splits = get_splits(x, y)
        ES = entropy(y)
        ESv = 0
        nt = len(y)
        if nt != 0:
            for i in range(len(splits) + 1):
                Sv = iloc_ranges(y, x, splits, i)
                n = len(Sv)
                ESv += - (n/nt)*entropy(Sv)
        return ES - ESv

    def get_max_ig(self, X: pd.DataFrame, y: pd.Series, X_cat_cols: List) -> str:
        """Identifies the column of X with the maximum info gain related to the target y

        Parameters
        ----------
        X : pd.DataFrame
            Input data
        y : pd.Series
            Target data
        X_cat_cols : List
            List of categorical columns of X

        Returns
        -------
        str
            Name of the column with maximum information gain
        """
        dct = {}
        cols = list(X.columns)
        for attr in cols:
            if attr in X_cat_cols:
                dct[attr] = self.info_gain_cat(X[attr], y)
            else:
                dct[attr] = self.info_gain_con(X[attr], y)
        return max(dct, key=dct.get)
    
    def iloc_ranges(self, y: pd.Series, x: pd.Series, splits: List, i: int) -> pd.Series:
        """Filters the data from the series y for which the continuous data x is between the values split[i-1] and split[i]

        Parameters
        ----------
        x : pd.Series
            Continuous data to use as base for the filtering
        y : pd.Series or pd.DataFrame
            Data to be filtered
        splits : List
            Values at which the values of x can be splitted
        i : int
            Index of the split to be used


        Returns
        -------
        pd.Series
            Filtered data
        """
        if len(x) > 0:
            if i > 0 and i < len(splits):
                Sv = y.loc[(x>splits[i-1]) & (x<=splits[i])]
            elif i == 0:
                Sv = y.loc[x<=splits[0]]
            else:
                Sv = y.loc[x>splits[-1]]
            return Sv
        return pd.Series([])

    def recover_index(self, val: float, splits: List) -> int:
        """Recovers the index at which val falls whitin the range of the values specified by splits

        Parameters
        ----------
        val : pd.Series
            Value to evaluate
        splits : List
            Limits of the split ranges.

        Returns
        -------
        int
            Recovered index
        """
        for i,v in enumerate(splits):
            if i > 0:
                if val > splits[i-1] and val <= v:
                    return i
            else:
                if val <= v:
                    return i
        return len(splits)

# %%
dt = Decision_Tree()
res_dict = dt.des_tree_nodes(X, y, X_cat_cols)

# %%
def predict_single(x, res_dict):
    tp = res_dict['type']
    attr = res_dict['attr']
    print(attr)
    if tp == 'cat':
        res = res_dict['res'][x[attr]]
        print(tp, x[attr], res_dict['res'].keys(), res_dict)
    else:
        val = res_dict['vals']
        i = recover_index(x[attr],val)
        res = res_dict['res'][str(i)]
        print(tp, x[attr], val, i, res_dict['res'].keys(), res_dict)
    
    if isinstance(res,dict):
        return predict_single(x, res)
    else:
        return res
    
def predict(X, res_dict):
    return X.apply(lambda x: predict_single(x, res_dict), axis=1)

# %%
#y_p = predict(X, res_dict)
print(X.iloc[0])
y_p = predict_single(X.iloc[0], res_dict)
y_p, y.iloc[0]
# Out:
# Gender              1.0
# Ever_Married        1.0
# Age                22.0
# Graduated           1.0
# Profession          6.0
# Work_Experience     1.0
# Spending_Score      2.0
# Family_Size         4.0
# Segmentation        3.0
# Name: 0, dtype: float64
# Gender
# cat 1.0 dict_keys([0, 1]) {'attr': 'Gender', 'type': 'cat', 'vals': array([0, 1], dtype=int8), 'res': {0: {'attr': 'Work_Experience', 'type': 'cont', 'vals': array([0., 1.]), 'res': {'0': {'attr': 'Ever_Married', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Graduated', 'type': 'cat', 'vals': array([1, 2], dtype=int8), 'res': {1: {'attr': 'Age', 'type': 'cont', 'vals': array([22. , 25.5, 51. ]), 'res': {'0': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 3], dtype=int8), 'res': {0: 3, 3: {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 6], dtype=int8), 'res': {0: 3, 6: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3. , 3.5, 6. ]), 'res': {'0': 6, '2': 6}}}}}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([6], dtype=int8), 'res': {6: 6}}, '2': {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: 4, 1: 6, 2: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 2], dtype=int8), 'res': {0: {'attr': 'Profession', 'type': 'cat', 'vals': array([3, 4], dtype=int8), 'res': {3: 6, 4: 3}}, 2: 6}}}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([8], dtype=int8), 'res': {8: 3}}}}, 2: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2., 4.]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([63.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1], dtype=int8), 'res': {1: 6}}}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([30., 57.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([0], dtype=int8), 'res': {0: 4}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([3], dtype=int8), 'res': {3: 2}}}}}}, 1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1., 4., 8.]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([29., 38., 50.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([4], dtype=int8), 'res': {4: 1}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([5], dtype=int8), 'res': {5: 3}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([1], dtype=int8), 'res': {1: 0}}}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([29.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([7], dtype=int8), 'res': {7: 2}}}}, '2': {'attr': 'Age', 'type': 'cont', 'vals': array([28.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([2], dtype=int8), 'res': {2: 4}}}}}}, 2: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1. , 1.5, 4. ]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([25., 39., 41.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([7], dtype=int8), 'res': {7: 6}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([1], dtype=int8), 'res': {1: 7}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([6], dtype=int8), 'res': {6: 4}}}}, '2': {'attr': 'Age', 'type': 'cont', 'vals': array([30. , 41. , 49.5]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([2], dtype=int8), 'res': {2: 3}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([9], dtype=int8), 'res': {9: 6}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([1], dtype=int8), 'res': {1: 2}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([1], dtype=int8), 'res': {1: 2}}}}, '3': {'attr': 'Age', 'type': 'cont', 'vals': array([33.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([6], dtype=int8), 'res': {6: 3}}}}}}}}}}, 1: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([2], dtype=int8), 'res': {2: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3.]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([22., 39.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([4, 6], dtype=int8), 'res': {4: 3,  ...
# Work_Experience
# cont 1.0 [1.] 0 dict_keys(['0', '1']) {'attr': 'Work_Experience', 'type': 'cont', 'vals': array([1.]), 'res': {'0': {'attr': 'Ever_Married', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([47., 72.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([5], dtype=int8), 'res': {5: 4}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([8], dtype=int8), 'res': {8: 6}}}}, 1: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3.]), 'res': {'0': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([43., 60.]), 'res': {'0': 3, '1': 4}}}}}}, 1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0., 2.]), 'res': {'0': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 3], dtype=int8), 'res': {0: 4, 3: {'attr': 'Age', 'type': 'cont', 'vals': array([22., 30.]), 'res': {'0': 3, '1': 6}}}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([61., 81.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([9], dtype=int8), 'res': {9: 6}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([5], dtype=int8), 'res': {5: 4}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([8], dtype=int8), 'res': {8: 6}}}}, '2': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 3], dtype=int8), 'res': {0: 6, 3: {'attr': 'Age', 'type': 'cont', 'vals': array([19., 52.]), 'res': {'0': 4, '1': 6}}}}}}, 2: {'attr': 'Profession', 'type': 'cat', 'vals': array([4, 6, 8], dtype=int8), 'res': {4: 6, 6: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([2, 3], dtype=int8), 'res': {2: 6, 3: {'attr': 'Age', 'type': 'cont', 'vals': array([20., 22.]), 'res': {'0': 6, '1': 4}}}}, 8: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1.]), 'res': {'0': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0], dtype=int8), 'res': {0: 6}}}}}}}}, 2: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4], dtype=int8), 'res': {1: {'attr': 'Age', 'type': 'cont', 'vals': array([37., 56.]), 'res': {'0': 3, '1': 6}}, 2: 4, 4: 6}}, 1: {'attr': 'Age', 'type': 'cont', 'vals': array([55.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 3, 4], dtype=int8), 'res': {1: 6, 3: 4, 4: 6}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([1], dtype=int8), 'res': {1: 6}}}}, 2: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 4], dtype=int8), 'res': {1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3., 5.]), 'res': {'0': 3, '1': 4}}, 4: 3}}}}, 1: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([1, 3], dtype=int8), 'res': {1: 6, 3: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2.]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([47., 60.]), 'res': {'0': 3, '1': 6}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([53.]), 'res': {'0': 6}}}}}}, 2: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 3, 5, 6], dtype=int8), 'res': {1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0., 1., 4.]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([45., 66.]), 'res': {'0': 6, '1': 3}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([40.]), 'res': {'0': 7}}, '2': {'attr': 'Age', 'type': 'cont', 'vals': array([43., 52.]), 'res': {'0': 3, '1': 4}}}}, 3: 4, 5: 1, 6: 6}}}}}}, 1: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([2], dtype=int8), 'res': {2: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 1, 2, 3], dtype=int8), 'res': {0: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: { ...
# Ever_Married
# cat 1.0 dict_keys([0, 1, 2]) {'attr': 'Ever_Married', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([47., 72.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([5], dtype=int8), 'res': {5: 4}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([8], dtype=int8), 'res': {8: 6}}}}, 1: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3.]), 'res': {'0': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([43., 60.]), 'res': {'0': 3, '1': 4}}}}}}, 1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0., 2.]), 'res': {'0': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 3], dtype=int8), 'res': {0: 4, 3: {'attr': 'Age', 'type': 'cont', 'vals': array([22., 30.]), 'res': {'0': 3, '1': 6}}}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([61., 81.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([9], dtype=int8), 'res': {9: 6}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([5], dtype=int8), 'res': {5: 4}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([8], dtype=int8), 'res': {8: 6}}}}, '2': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 3], dtype=int8), 'res': {0: 6, 3: {'attr': 'Age', 'type': 'cont', 'vals': array([19., 52.]), 'res': {'0': 4, '1': 6}}}}}}, 2: {'attr': 'Profession', 'type': 'cat', 'vals': array([4, 6, 8], dtype=int8), 'res': {4: 6, 6: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([2, 3], dtype=int8), 'res': {2: 6, 3: {'attr': 'Age', 'type': 'cont', 'vals': array([20., 22.]), 'res': {'0': 6, '1': 4}}}}, 8: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1.]), 'res': {'0': {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0], dtype=int8), 'res': {0: 6}}}}}}}}, 2: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4], dtype=int8), 'res': {1: {'attr': 'Age', 'type': 'cont', 'vals': array([37., 56.]), 'res': {'0': 3, '1': 6}}, 2: 4, 4: 6}}, 1: {'attr': 'Age', 'type': 'cont', 'vals': array([55.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 3, 4], dtype=int8), 'res': {1: 6, 3: 4, 4: 6}}, '1': {'attr': 'Profession', 'type': 'cat', 'vals': array([1], dtype=int8), 'res': {1: 6}}}}, 2: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 4], dtype=int8), 'res': {1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3., 5.]), 'res': {'0': 3, '1': 4}}, 4: 3}}}}, 1: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([1, 3], dtype=int8), 'res': {1: 6, 3: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2.]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([47., 60.]), 'res': {'0': 3, '1': 6}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([53.]), 'res': {'0': 6}}}}}}, 2: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 3, 5, 6], dtype=int8), 'res': {1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0., 1., 4.]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([45., 66.]), 'res': {'0': 6, '1': 3}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([40.]), 'res': {'0': 7}}, '2': {'attr': 'Age', 'type': 'cont', 'vals': array([43., 52.]), 'res': {'0': 3, '1': 4}}}}, 3: 4, 5: 1, 6: 6}}}}}}, 1: {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([2], dtype=int8), 'res': {2: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 1, 2, 3], dtype=int8), 'res': {0: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([27., 50.]), 'res': {'0': {'attr': 'Profes ...
# Spending_Score
# cat 2.0 dict_keys([2]) {'attr': 'Spending_Score', 'type': 'cat', 'vals': array([2], dtype=int8), 'res': {2: {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 1, 2, 3], dtype=int8), 'res': {0: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([27., 50.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([2, 5], dtype=int8), 'res': {2: 2, 5: 4}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([8], dtype=int8), 'res': {8: 4}}}}, 1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0. , 1.5, 2. , 2.5, 3. ]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 3, 4], dtype=int8), 'res': {1: 4, 3: 4, 4: 3}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([35., 40., 47., 59.]), 'res': {'0': 4, '1': 6, '2': 6, '3': 6, '4': 6}}, '2': {'attr': 'Age', 'type': 'cont', 'vals': array([28., 33.]), 'res': {'0': 6, '1': 6, '2': 6}}, '4': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 3, 4, 5, 6, 9], dtype=int8), 'res': {1: 2, 2: 6, 3: 6, 4: 6, 5: 6, 6: 2, 9: 3}}, '5': {'attr': 'Age', 'type': 'cont', 'vals': array([27.5, 29. ]), 'res': {'0': 6, '1': 4, '2': 6}}}}, 2: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0. , 0.5, 1. , 2. , 3. ]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6], dtype=int8), 'res': {1: 6, 2: 6, 4: 1, 6: 6}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 3, 4, 9], dtype=int8), 'res': {0: 6, 1: 6, 2: 6, 3: 2, 4: 6, 9: 6}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6, 8, 9], dtype=int8), 'res': {1: 6, 2: 6, 4: 6, 6: 3, 8: 6, 9: 3}}, '4': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 3, 4, 5, 6], dtype=int8), 'res': {1: 6, 2: 6, 3: 6, 4: 6, 5: 6, 6: 6}}, '5': {'attr': 'Age', 'type': 'cont', 'vals': array([29.5, 31. , 32. , 39.5, 57. ]), 'res': {'0': 6, '1': 2, '2': 6, '3': 3, '4': 6}}}}}}, 1: {'attr': 'Graduated', 'type': 'cat', 'vals': array([1, 2], dtype=int8), 'res': {1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2.5, 3. , 3.5, 4. ]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([29., 31.]), 'res': {'0': 6, '1': 4, '2': 4}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([24., 27., 31., 32.]), 'res': {'0': 3, '1': 4, '2': 6, '4': 6}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([2, 6], dtype=int8), 'res': {2: 6, 6: 6}}, '4': {'attr': 'Age', 'type': 'cont', 'vals': array([28. , 28.5, 29.5]), 'res': {'0': 6, '2': 4, '3': 6}}}}, 2: {'attr': 'Age', 'type': 'cont', 'vals': array([26. , 29. , 32. , 38. , 39. , 39.5, 43. ]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 4, 6], dtype=int8), 'res': {1: 0, 4: 3, 6: 6}}, '1': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3. , 3.5, 4. , 6. ]), 'res': {'0': 6, '2': 6, '3': 6, '4': 4}}, '2': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1., 3., 4.]), 'res': {'0': 3, '1': 6, '2': 6, '3': 6}}, '3': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1. , 1.5, 4. ]), 'res': {'0': 6, '2': 6, '3': 6}}, '4': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1., 2., 3.]), 'res': {'0': 6, '1': 6, '2': 1}}, '6': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4], dtype=int8), 'res': {1: 6, 2: 2, 4: 6}}, '7': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 4, 8], dtype=int8), 'res': {0: 6, 1: 6, 2: 6, 4: 6, 8: 6}}}}}}, 2: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: 6, 1: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6, 9], dtype=int8), 'res': {1: {'attr': 'Age', 'type': 'cont', 'vals': array([31., 33.]), 'res': {'0': 2, '1': 3}}, 2: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2. , 4. , 4.5, 5. ]), 'res': {'0': 3, '1': 6, '3': 4}}, 4: {'attr': 'Age', 'type': 'cont', 'vals': array([19., 24.]), 'res': {'0': 6, '2': 4}}, 6: {'attr': 'Age', 'type': 'cont', 'vals': array ...
# Segmentation
# cat 3.0 dict_keys([0, 1, 2, 3]) {'attr': 'Segmentation', 'type': 'cat', 'vals': array([0, 1, 2, 3], dtype=int8), 'res': {0: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([27., 50.]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([2, 5], dtype=int8), 'res': {2: 2, 5: 4}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([8], dtype=int8), 'res': {8: 4}}}}, 1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0. , 1.5, 2. , 2.5, 3. ]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 3, 4], dtype=int8), 'res': {1: 4, 3: 4, 4: 3}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([35., 40., 47., 59.]), 'res': {'0': 4, '1': 6, '2': 6, '3': 6, '4': 6}}, '2': {'attr': 'Age', 'type': 'cont', 'vals': array([28., 33.]), 'res': {'0': 6, '1': 6, '2': 6}}, '4': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 3, 4, 5, 6, 9], dtype=int8), 'res': {1: 2, 2: 6, 3: 6, 4: 6, 5: 6, 6: 2, 9: 3}}, '5': {'attr': 'Age', 'type': 'cont', 'vals': array([27.5, 29. ]), 'res': {'0': 6, '1': 4, '2': 6}}}}, 2: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0. , 0.5, 1. , 2. , 3. ]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6], dtype=int8), 'res': {1: 6, 2: 6, 4: 1, 6: 6}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 3, 4, 9], dtype=int8), 'res': {0: 6, 1: 6, 2: 6, 3: 2, 4: 6, 9: 6}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6, 8, 9], dtype=int8), 'res': {1: 6, 2: 6, 4: 6, 6: 3, 8: 6, 9: 3}}, '4': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 3, 4, 5, 6], dtype=int8), 'res': {1: 6, 2: 6, 3: 6, 4: 6, 5: 6, 6: 6}}, '5': {'attr': 'Age', 'type': 'cont', 'vals': array([29.5, 31. , 32. , 39.5, 57. ]), 'res': {'0': 6, '1': 2, '2': 6, '3': 3, '4': 6}}}}}}, 1: {'attr': 'Graduated', 'type': 'cat', 'vals': array([1, 2], dtype=int8), 'res': {1: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2.5, 3. , 3.5, 4. ]), 'res': {'0': {'attr': 'Age', 'type': 'cont', 'vals': array([29., 31.]), 'res': {'0': 6, '1': 4, '2': 4}}, '1': {'attr': 'Age', 'type': 'cont', 'vals': array([24., 27., 31., 32.]), 'res': {'0': 3, '1': 4, '2': 6, '4': 6}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([2, 6], dtype=int8), 'res': {2: 6, 6: 6}}, '4': {'attr': 'Age', 'type': 'cont', 'vals': array([28. , 28.5, 29.5]), 'res': {'0': 6, '2': 4, '3': 6}}}}, 2: {'attr': 'Age', 'type': 'cont', 'vals': array([26. , 29. , 32. , 38. , 39. , 39.5, 43. ]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 4, 6], dtype=int8), 'res': {1: 0, 4: 3, 6: 6}}, '1': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([3. , 3.5, 4. , 6. ]), 'res': {'0': 6, '2': 6, '3': 6, '4': 4}}, '2': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1., 3., 4.]), 'res': {'0': 3, '1': 6, '2': 6, '3': 6}}, '3': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1. , 1.5, 4. ]), 'res': {'0': 6, '2': 6, '3': 6}}, '4': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1., 2., 3.]), 'res': {'0': 6, '1': 6, '2': 1}}, '6': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4], dtype=int8), 'res': {1: 6, 2: 2, 4: 6}}, '7': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 4, 8], dtype=int8), 'res': {0: 6, 1: 6, 2: 6, 4: 6, 8: 6}}}}}}, 2: {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: 6, 1: {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6, 9], dtype=int8), 'res': {1: {'attr': 'Age', 'type': 'cont', 'vals': array([31., 33.]), 'res': {'0': 2, '1': 3}}, 2: {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2. , 4. , 4.5, 5. ]), 'res': {'0': 3, '1': 6, '3': 4}}, 4: {'attr': 'Age', 'type': 'cont', 'vals': array([19., 24.]), 'res': {'0': 6, '2': 4}}, 6: {'attr': 'Age', 'type': 'cont', 'vals': array([25.5, 26. , 28. , 29. , 29.5, 33. ]), 'res': {'0': 6, '1': 6, '2': 6, '3': ...
# Graduated
# cat 1.0 dict_keys([0, 1, 2]) {'attr': 'Graduated', 'type': 'cat', 'vals': array([0, 1, 2], dtype=int8), 'res': {0: {'attr': 'Age', 'type': 'cont', 'vals': array([21. , 27.5]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([6], dtype=int8), 'res': {6: 3}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([0], dtype=int8), 'res': {0: 6}}}}, 1: {'attr': 'Age', 'type': 'cont', 'vals': array([21. , 21.5, 22. , 23.5]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6, 9], dtype=int8), 'res': {1: 4, 2: 6, 4: 6, 6: 6, 9: 1}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 3, 6, 9], dtype=int8), 'res': {0: 1, 1: 6, 2: 2, 3: 6, 6: 6, 9: 4}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 3, 4, 6, 9], dtype=int8), 'res': {0: 4, 1: 6, 2: 6, 3: 4, 4: 4, 6: 6, 9: 6}}, '4': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2. , 3. , 3.5, 4. ]), 'res': {'0': 6, '1': 6, '3': 6, '4': 6}}}}, 2: {'attr': 'Age', 'type': 'cont', 'vals': array([28. , 28.5, 30. , 30.5, 33.5]), 'res': {'0': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0. , 2.5, 3. , 3.5]), 'res': {'0': 3, '1': 6, '2': 6, '4': 6}}, '2': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0., 2., 3., 4.]), 'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 3}}, '4': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([0., 2., 3., 4., 6.]), 'res': {'0': 6, '1': 6, '2': 6, '3': 6, '4': 6}}, '5': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([1., 2., 3.]), 'res': {'0': 6, '1': 6, '2': 6, '3': 6}}}}}}
# Age
# cont 22.0 [21.  21.5 22.  23.5] 2 dict_keys(['0', '2', '3', '4']) {'attr': 'Age', 'type': 'cont', 'vals': array([21. , 21.5, 22. , 23.5]), 'res': {'0': {'attr': 'Profession', 'type': 'cat', 'vals': array([1, 2, 4, 6, 9], dtype=int8), 'res': {1: 4, 2: 6, 4: 6, 6: 6, 9: 1}}, '2': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 3, 6, 9], dtype=int8), 'res': {0: 1, 1: 6, 2: 2, 3: 6, 6: 6, 9: 4}}, '3': {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 3, 4, 6, 9], dtype=int8), 'res': {0: 4, 1: 6, 2: 6, 3: 4, 4: 4, 6: 6, 9: 6}}, '4': {'attr': 'Family_Size', 'type': 'cont', 'vals': array([2. , 3. , 3.5, 4. ]), 'res': {'0': 6, '1': 6, '3': 6, '4': 6}}}}
# Profession
# cat 6.0 dict_keys([0, 1, 2, 3, 6, 9]) {'attr': 'Profession', 'type': 'cat', 'vals': array([0, 1, 2, 3, 6, 9], dtype=int8), 'res': {0: 1, 1: 6, 2: 2, 3: 6, 6: 6, 9: 4}}
# (6, 4)

# %%
np.set_printoptions(formatter={'float_kind':'{:4.0f}'.format})
cm = utl.confusion_matrix(y, y_p)
acc = utl.accuracy_classification(cm)
pres = utl.presicion_classification(cm)
rec = utl.recall_classification(cm)
f1 = utl.fbeta_classification(cm)

acc, pres, rec, f1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 2
#       1 np.set_printoptions(formatter={'float_kind':'{:4.0f}'.format})
# ----> 2 cm = utl.confusion_matrix(y, y_p)
#       3 acc = utl.accuracy_classification(cm)
#       4 pres = utl.presicion_classification(cm)
#
# File e:\JupyterNotebooks\2023\ML Models\MLModels\notebooks\../scripts\utils.py:72, in confusion_matrix(y, y_p)
#      70 for i in range(len(y)):
#      71     k = np.where(cats == y.iloc[i])[0][0]
# ---> 72     l = np.where(cats == y_p.iloc[i])[0][0]
#      73     conf_matr[k][l] = conf_matr[k][l] + 1
#      74 return conf_matr
#
# AttributeError: 'numpy.int8' object has no attribute 'iloc'

# %%
cm
# Out:
# array([[  17,    0,    0,    1,    5,    1,   52,    0],
#        [   0,   35,    3,    5,    5,    0,   84,    1],
#        [   0,    2,   93,    7,   12,    2,  306,    0],
#        [   0,    4,   11,  204,   43,    2,  556,    2],
#        [   1,    4,    8,   21,  387,    3,  659,    6],
#        [   0,    1,    1,    2,    5,   26,   50,    0],
#        [   3,   14,   26,   45,  117,    7, 5016,   10],
#        [   0,    0,    1,    3,   10,    0,  140,   49]])

# %% [markdown]
# ## Comparison with scikit learn

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state=0).fit(X,y)
y_pred_skl_np = clf.predict(X)
y_pred_skl = pd.Series(y_pred_skl_np)

# %%
cm_skl = utl.confusion_matrix(y, y_pred_skl)
acc_skl = utl.accuracy_classification(cm_skl)
pres_skl = utl.presicion_classification(cm_skl)
rec_skl = utl.recall_classification(cm_skl)
f1_skl = utl.fbeta_classification(cm_skl)

acc_skl, pres_skl, rec_skl, f1_skl
# Out:
# (0.9556271690629649, 0.9342105263157895, 0.922077922077922, 0.9281045751633986)

# %%
cm_skl
# Out:
# array([[  71,    0,    0,    0,    0,    0,    5,    0],
#        [   0,  124,    0,    0,    1,    0,    8,    0],
#        [   1,    1,  399,    0,    1,    0,   20,    0],
#        [   0,    2,    9,  770,    2,    0,   38,    1],
#        [   2,    2,   16,   14, 1025,    0,   29,    1],
#        [   0,    0,    0,    0,    1,   83,    1,    0],
#        [   3,    4,   36,   61,   66,    4, 5063,    1],
#        [   0,    0,    1,    3,    4,    0,   20,  175]])

# %%
tst_splits = [20.,30.,50.,70.,110.]
tst_vals = [10.,25.,30.,41.,51.,110.,200.]
for t in tst_vals:
    print(recover_index(t, tst_splits))
# Out:
# 0
# 1
# 1
# 2
# 3
# 4
# 5
